# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
from obspy.core.event import ResourceIdentifier
import numpy as np

server_IP = 'http://10.100.100.232'
port_fdsn = "8091"
    

starttime = UTCDateTime("2018 04 25 135959")    

endtime = UTCDateTime("2018 04 25 235959")

client = Client(server_IP+":"+port_fdsn)

# %%
# catálogo de eventos correspondiente al select
cat = client.get_events(starttime=starttime, endtime=endtime)
print len(cat)
# Out:
# 42

# %%
# seleccionando el primer evento del catálogo
event = cat[4]
print event
# Out:
# Event:	2018-04-25T22:18:24.788285Z | +14.314,  -89.985 | 4.9 Mw(mB) | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibzn")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='USGS', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 23, 12, 297181))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426043321.931703.13933")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426043321.931703.13933#netMag.Mw(mB)")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements

# %%
# seleccionando el origen preferido del evento
pref_origin = event.preferred_origin()
print pref_origin
# Out:
# Origin
# 	        resource_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426043321.931703.13933")
# 	               time: UTCDateTime(2018, 4, 25, 22, 18, 24, 788285) [uncertainty=2.690145831]
# 	          longitude: -89.9849 [uncertainty=9.5]
# 	           latitude: 14.3144 [uncertainty=8.123081392]
# 	              depth: 191270.0 [uncertainty=24146.99931]
# 	          method_id: ResourceIdentifier(id="smi:scs/0.7/LOCSAT")
# 	     earth_model_id: ResourceIdentifier(id="smi:scs/0.7/iasp91")
# 	            quality: OriginQuality(associated_phase_count=24, used_phase_count=24, associated_station_count=24, used_station_count=24, depth_phase_count=0, standard_error=1.154909869, azimuthal_gap=288.7565536, minimum_distance=13.53221893, maximum_distance=19.24248123, median_distance=16.58061981)
# 	 origin_uncertainty: OriginUncertainty(min_horizontal_uncertainty=14.50514603, max_horizontal_uncertainty=45.94422913, azimuth_max_horizontal_uncertainty=102.8152084, preferred_description='horizontal uncertainty')
# 	    evaluation_mode: 'manual'
# 	  evaluation_status: 'confirmed'
# 	      creation_info: CreationInfo(agency_id='USGS', author='lperez@proc3', creation_time=UTCDateTime(2018, 4, 26, 4, 33, 21, 932035))

# %%
print event.preferred_origin_id.id

event.preferred_origin_id = ResourceIdentifier(id=event.preferred_origin_id.id.replace("#","_").replace("@","a"))
event.preferred_magnitude_id = ResourceIdentifier(id=event.preferred_origin_id.id.replace("#","_").replace("@","a"))
print event.preferred_origin_id.id

event.write("sismo2.6.xml", format="QUAKEML", validate=True)
# Out:
# smi:scs/0.7/Origin#20180326041247.726698.14351
# smi:scs/0.7/Origin_20180326041247.726698.14351

# %%
# Out:
# CreationInfo()

# %%
for event in cat:
    try:
        #print event
        event_time = event.preferred_origin().time
        print event
        event_name = event.resource_id.resource_id.split('/')[2]
        print event_name
        #event.write(event_name, format="QUAKEML")
        print 'Output file name: ' +  event_name
    except Exception as e:
        print e
        print event_name
        continue
# Out:
# Event:	2018-04-25T23:58:37.479999Z |  +8.744,  -73.705 | 1.674332358 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018iccu")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 5, 39, 16, 677376))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426053746.1984.14480")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426053756.659681.14490")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018iccu
# Output file name: SGC2018iccu
# Event:	2018-04-25T23:13:37.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018icbi")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 5, 3, 46, 114364))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426050304.452595.14218")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018icbi
# Output file name: SGC2018icbi
# Event:	2018-04-25T22:51:41.750000Z |  +6.763,  -73.140 | 1.315688539 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018icap")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 4, 55, 52, 922235))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426045436.37264.14145")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426045453.528779.14152")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018icap
# Output file name: SGC2018icap
# Event:	2018-04-25T22:27:40.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibzu")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 4, 47, 57, 760696))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426044717.171881.14121")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibzu
# Output file name: SGC2018ibzu
# Event:	2018-04-25T22:18:24.788285Z | +14.314,  -89.985 | 4.9 Mw(mB) | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibzn")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='USGS', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 23, 12, 297181))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426043321.931703.13933")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426043321.931703.13933#netMag.Mw(mB)")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibzn
# Output file name: SGC2018ibzn
# Event:	2018-04-25T22:17:43.509999Z |  +6.764,  -73.070 | 1.674642645 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibzm")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 4, 42, 48, 950233))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426044136.827769.14038")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426044142.873242.14049")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibzm
# Output file name: SGC2018ibzm
# Event:	2018-04-25T21:58:36.170000Z | +10.146,  -71.960 | 2.464859501 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibyw")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 21, 59, 16, 945363))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426042906.469621.13788")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426042918.55239.13807")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibyw
# Output file name: SGC2018ibyw
# Event:	2018-04-25T21:33:43.000000Z |  +2.328,  -76.397
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibya")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 4, 21, 58, 272631))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426042117.450386.13722")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibya
# Output file name: SGC2018ibya
# Event:	2018-04-25T21:29:18.000000Z | +11.020,  -72.882
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibxw")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 4, 15, 28, 170067))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426041447.026139.13679")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibxw
# Output file name: SGC2018ibxw
# Event:	2018-04-25T20:39:32.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibwg")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 3, 52, 39, 445358))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426035158.504996.14003")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibwg
# Output file name: SGC2018ibwg
# Event:	2018-04-25T20:25:46.000000Z |  +3.003,  -78.167
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibvu")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 3, 47, 31, 194364))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426034649.872651.13992")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibvu
# Output file name: SGC2018ibvu
# Event:	2018-04-25T20:20:27.329999Z |  +7.111,  -72.120 | 1.859423487 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibvp")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 3, 38, 8, 948389))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426034325.422184.13939")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426034420.565389.13946")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibvp
# Output file name: SGC2018ibvp
# Event:	2018-04-25T20:08:34.000000Z | +11.020,  -72.882
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibvf")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 26, 3, 33, 16, 58043))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426033214.583852.13789")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibvf
# Output file name: SGC2018ibvf
# Event:	2018-04-25T20:00:28.820000Z |  +6.644,  -74.079 | 2.278713968 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibuy")
# 	             event_type: 'earthquake'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 20, 1, 16, 939573))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180426032950.023244.13732")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180426032957.267032.13754")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibuy
# Output file name: SGC2018ibuy
# Event:	2018-04-25T19:45:28.070000Z |  +4.877,  -76.241 | 1.74048088 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibul")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 39, 25, 527528))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425233837.934133.16177")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425233844.53667.16194")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibul
# Output file name: SGC2018ibul
# Event:	2018-04-25T18:59:26.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibsy")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 32, 14, 996348))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425233134.043132.16154")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibsy
# Output file name: SGC2018ibsy
# Event:	2018-04-25T18:44:30.589999Z |  +6.800,  -73.172 | 1.259210812 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibsl")
# 	             event_type: 'other event'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 30, 46, 158598))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425233003.340849.16142")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425233003.340849.16142#netMag.MLr")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibsl
# Output file name: SGC2018ibsl
# Event:	2018-04-25T18:14:17.929999Z | +11.083,  -72.858 | 1.634937956 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibrl")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 25, 35, 309933))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425232446.669304.16068")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425232455.047473.16083")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibrl
# Output file name: SGC2018ibrl
# Event:	2018-04-25T17:59:38.369999Z |  +9.659,  -73.451 | 1.850921445 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqz")
# 	             event_type: 'explosion'
# 	   event_type_certainty: 'known'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 18, 1, 26, 476907))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425231104.773632.15738")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425231111.599673.15759")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibqz
# Output file name: SGC2018ibqz
# Event:	2018-04-25T17:56:35.000000Z |  +7.752,  -75.533
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqw")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 22, 0, 872848))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425232120.490665.16034")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibqw
# Output file name: SGC2018ibqw
# Event:	2018-04-25T17:40:51.759999Z |  +6.804,  -73.171 | 1.481840956 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqi")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 18, 56, 835926))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425231828.368829.15937")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425231834.425034.15952")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibqi
# Output file name: SGC2018ibqi
# Event:	2018-04-25T17:38:05.219999Z |  +0.248,  -77.320 | 2.081761797 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqg")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 23, 16, 21, 364597))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425231907.16251.15978")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425231919.887553.15999")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibqg
# Output file name: SGC2018ibqg
# Event:	2018-04-25T17:33:55.679999Z |  +9.555,  -73.274 | 1.637361566 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqd")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 17, 34, 30, 866614))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425230844.387597.15631")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425230850.783809.15656")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibqd
# Output file name: SGC2018ibqd
# Event:	2018-04-25T17:30:35.670000Z |  +9.607,  -73.487 | 1.719463096 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibqa")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 17, 30, 58, 245283))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425230029.420921.15472")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425230033.631134.15491")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibqa
# Output file name: SGC2018ibqa
# Event:	2018-04-25T17:29:08.759999Z |  +9.563,  -73.466 | 1.936655851 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibpy")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 17, 29, 23, 818645))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425225639.004643.15320")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425225644.750794.15345")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibpy
# Output file name: SGC2018ibpy
# Event:	2018-04-25T17:06:32.329999Z |  +9.649,  -73.542 | 1.816238026 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibpf")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 17, 6, 51, 814436))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425224841.974044.15216")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425224852.574797.15233")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibpf
# Output file name: SGC2018ibpf
# Event:	2018-04-25T17:01:28.719999Z |  +9.632,  -73.534 | 1.524776032 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibpb")
# 	             event_type: 'explosion'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 17, 1, 49, 641983))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425224438.600102.15177")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425224449.525009.15196")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibpb
# Output file name: SGC2018ibpb
# Event:	2018-04-25T16:57:27.359999Z |  +6.804,  -73.109 | 1.836664716 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018iboy")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 42, 47, 920538))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425224146.954266.15094")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425224207.398935.15125")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018iboy
# Output file name: SGC2018iboy
# Event:	2018-04-25T16:57:19.000000Z | +11.020,  -72.882
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibox")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 37, 43, 288234))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425223659.944019.15056")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibox
# Output file name: SGC2018ibox
# Event:	2018-04-25T16:45:30.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibon")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 36, 16, 743003))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425223535.328179.15047")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibon
# Output file name: SGC2018ibon
# Event:	2018-04-25T16:40:32.000000Z |  +2.312,  -75.639 | 1.117601315 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018iboj")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 34, 17, 305085))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425223316.948457.15023")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425223322.790885.15036")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018iboj
# Output file name: SGC2018iboj
# Event:	2018-04-25T16:27:25.489999Z |  +6.792,  -73.166 | 1.829355446 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibnx")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 31, 16, 828520))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425223029.518505.14953")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425223033.597827.14978")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibnx
# Output file name: SGC2018ibnx
# Event:	2018-04-25T16:25:41.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibnw")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 27, 9, 956703))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425222623.871589.14920")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibnw
# Output file name: SGC2018ibnw
# Event:	2018-04-25T16:18:41.679999Z |  +6.824,  -73.178 | 1.505751173 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibnq")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 25, 49, 29021))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425222455.347161.14890")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425222500.991099.14907")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibnq
# Output file name: SGC2018ibnq
# Event:	2018-04-25T16:15:24.089999Z |  +5.871,  -73.725 | 1.480647047 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibnn")
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 23, 20, 365372))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425222227.28693.14687")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Magnitude#20180425222237.078143.14720")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibnn
# Output file name: SGC2018ibnn
# Event:	2018-04-25T15:40:15.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibmj")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 18, 5, 601204))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425221725.303227.14627")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibmj
# Output file name: SGC2018ibmj
# Event:	2018-04-25T15:29:23.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibma")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 16, 57, 882156))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425221617.623183.14618")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibma
# Output file name: SGC2018ibma
# Event:	2018-04-25T14:58:43.149999Z |  +6.756,  -73.179 | 1.415813989 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibkz")
# 	             event_type: 'other event'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 12, 7, 303675))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425221126.906199.14604")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425221126.906199.14604#netMag.MLr")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibkz
# Output file name: SGC2018ibkz
# Event:	2018-04-25T14:43:00.000000Z |  +7.018,  -76.210
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibkm")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 10, 37, 699303))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425220957.270914.14589")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibkm
# Output file name: SGC2018ibkm
# Event:	2018-04-25T14:36:48.000000Z | +11.020,  -72.882
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibki")
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 8, 9, 983400))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425220647.454852.14562")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibki
# Output file name: SGC2018ibki
# Event:	2018-04-25T14:36:44.829999Z |  +6.745,  -73.162 | 1.371799946 MLr | manual
#
# 	            resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibkh")
# 	             event_type: 'other event'
# 	          creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 22, 0, 36, 230241))
# 	    preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425215959.63731.14443")
# 	 preferred_magnitude_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425215959.63731.14443#netMag.MLr")
# 	                   ---------
# 	     event_descriptions: 1 Elements
# 	                origins: 1 Elements
# 	             magnitudes: 1 Elements
# SGC2018ibkh
# Output file name: SGC2018ibkh
# Event:	2018-04-25T14:07:59.359999Z |  +4.771,  -75.915 | manual
#
# 	         resource_id: ResourceIdentifier(id="smi:scs/0.7/SGC2018ibji")
# 	          event_type: 'other event'
# 	       creation_info: CreationInfo(agency_id='SGC', author='scevent@seismo1.sgc.gov.co', creation_time=UTCDateTime(2018, 4, 25, 21, 50, 33, 171642))
# 	 preferred_origin_id: ResourceIdentifier(id="smi:scs/0.7/Origin#20180425214939.271013.14354")
# 	                ---------
# 	  event_descriptions: 1 Elements
# 	             origins: 1 Elements
# SGC2018ibji
# Output file name: SGC2018ibji
